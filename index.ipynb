# %% [markdown]
# # More Practice With SQL Queries - Lab
#
# ## Introduction
#
# In this lesson, we'll run through some practice questions to refresh your knowledge of SQL Queries!
#
# ## Objectives
#
# You will be able to:
#
# - Use `GROUP BY` statements in SQL to apply aggregate functions like: `COUNT`, `MAX`, `MIN`, and `SUM`
# - Decide and perform whichever type of join is best for retrieving desired data
# - Use the `HAVING` clause to compare different aggregates
# - Write subqueries to decompose complex queries
#
# ## Getting Started
#
# As in previous labs, we'll make use of the `sqlite3` library as well as Pandas. By combining them, we'll be able to write queries as Python strings, and make sure that the results are always returned as a Pandas DataFrame.
#
# We'll start by loading both libraries and connecting to the database we'll be using for this lab, `data.sqlite`. You may remember this database from a previous lab. As a refresher, here's the ERD diagram for this database:
#
# <img src='images/Database-Schema.png'>
#
# In the cell below:
#
# * Import the necessary libraries `pandas` and `sqlite3`
# * Establish a connection to the database `data.sqlite`
# * Get the `cursor` from the connection and store it in the variable `c`

# %%
import pandas as pd
import sqlite3
conn = sqlite3.Connection('data.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Basic Queries
#
# Now, let's review basic SQL queries. In the cell below:
#
# Write a query that gets the first name, last name, phone number, address, and credit limit for all customers in California with a credit limit greater than 25000.00.

# %%
# For the first query, the boilerplate for getting 
# the query into a DataFrame has been provided for you
c.execute("""SELECT contactFirstName, contactLastName, phone, addressLine1, creditLimit
             FROM customers
             WHERE creditLimit > 25000""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
Jupyter Notebook
index (unsaved changes) Current Kernel Logo 

Python 3

    File
    Edit
    View
    Insert
    Cell
    Kernel
    Help

More Practice With SQL Queries - Lab
Introduction

In this lesson, we'll run through some practice questions to refresh your knowledge of SQL Queries!
Objectives

You will be able to:

    Use GROUP BY statements in SQL to apply aggregate functions like: COUNT, MAX, MIN, and SUM
    Decide and perform whichever type of join is best for retrieving desired data
    Use the HAVING clause to compare different aggregates
    Write subqueries to decompose complex queries

Getting Started

As in previous labs, we'll make use of the sqlite3 library as well as Pandas. By combining them, we'll be able to write queries as Python strings, and make sure that the results are always returned as a Pandas DataFrame.

We'll start by loading both libraries and connecting to the database we'll be using for this lab, data.sqlite. You may remember this database from a previous lab. As a refresher, here's the ERD diagram for this database:

In the cell below:

    Import the necessary libraries pandas and sqlite3
    Establish a connection to the database data.sqlite
    Get the cursor from the connection and store it in the variable c

import pandas as pd

import sqlite3

conn = sqlite3.Connection('data.sqlite')

c = conn.cursor()

Basic Queries

Now, let's review basic SQL queries. In the cell below:

Write a query that gets the first name, last name, phone number, address, and credit limit for all customers in California with a credit limit greater than 25000.00.

# For the first query, the boilerplate for getting 

# the query into a DataFrame has been provided for you

c.execute("""SELECT contactFirstName, contactLastName, phone, addressLine1, creditLimit

             FROM customers

             WHERE creditLimit > 25000""")

df = pd.DataFrame(c.fetchall())

df.columns = [x[0] for x in c.description]

df
# Out:
#    contactFirstName contactLastName           phone  \
# 0              Jean            King      7025551838
# 1             Peter        Ferguson    03 9520 4555
# 2           Janine          Labrune      40.67.8555
# 3            Jonas       Bergulfsen      07-98 9555
# 4             Susan          Nelson      4155551450
# ..              ...             ...             ...
# 89             Rosa         Salazar      2155559857
# 90              Sue          Taylor      4155554312
# 91          Thomas            Smith  (171) 555-7555
# 92          Valarie          Franco      6175552555
# 93             Tony         Snowden   +64 9 5555500
#
#                     addressLine1  creditLimit
# 0                8489 Strong St.        71800
# 1              636 St Kilda Road       117300
# 2   67, rue des Cinquante Otages       118200
# 3         Erling Skakkes gate 78        81700
# 4                5677 Strong St.       210500
# ..                           ...          ...
# 89             11328 Douglas Av.        72600
# 90             2793 Furth Circle        60300
# 91               120 Hanover Sq.        43300
# 92                6251 Ingle Ln.        85100
# 93            Arenales 1938 3'A'       110000
#
# [94 rows x 5 columns]

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-1.png'>
#
# ## Aggregate Functions and GROUP BY
#
# Next, write a query that gets the average credit limit per state.

# %%
c.execute("""SELECT AVG(creditLimit), state
             FROM customers
             GROUP BY state""").fetchall()
# Out:
# [(61839.72602739726, ''),
#  (89950.0, 'BC'),
#  (83854.54545454546, 'CA'),
#  (57350.0, 'CT'),
#  (0.0, 'Co. Cork'),
#  (93900.0, 'Isle of Wight'),
#  (70755.55555555556, 'MA'),
#  (114200.0, 'NH'),
#  (43000.0, 'NJ'),
#  (100550.0, 'NSW'),
#  (71800.0, 'NV'),
#  (89966.66666666667, 'NY'),
#  (81200.0, 'Osaka'),
#  (84766.66666666667, 'PA'),
#  (0.0, 'Pretoria'),
#  (51600.0, 'Queensland'),
#  (48700.0, 'Québec'),
#  (94400.0, 'Tokyo'),
#  (88800.0, 'Victoria')]

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-2.png'>
#
# ## JOINs
#
# Now, write a query that uses JOIN statements to get the customer name, customer number, order number, status, and quantity ordered. Print only the head of this DataFrame.

# %%
c.execute("""SELECT c.customerName, c.customerNumber,
                    o.orderNumber, o.status, od.quantityOrdered
             FROM customers c JOIN orders o
                              ON c.customerNumber = o.customerNumber
                              JOIN orderdetails od
                              ON o.orderNumber = od.orderNumber
                              JOIN products o
                              ON od.productCode = p.productCode""").fetchall()
# Out:
# [('Atelier graphique', 103, 10123, 'Shipped', 26),
#  ('Atelier graphique', 103, 10123, 'Shipped', 34),
#  ('Atelier graphique', 103, 10123, 'Shipped', 46),
#  ('Atelier graphique', 103, 10123, 'Shipped', 50),
#  ('Atelier graphique', 103, 10298, 'Shipped', 32),
#  ('Atelier graphique', 103, 10298, 'Shipped', 39),
#  ('Atelier graphique', 103, 10345, 'Shipped', 43),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 21),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 22),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 22),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 23),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 25),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 32),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 36),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 42),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 42),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 43),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 45),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 46),
#  ('Signal Gift Stores', 112, 10124, 'Shipped', 49),
#  ('Signal Gift Stores', 112, 10278, 'Shipped', 23),
#  ('Signal Gift Stores', 112, 10278, 'Shipped', 25),
#  ('Signal Gift Stores', 112, 10278, 'Shipped', 29),
#  ('Signal Gift Stores', 112, 10278, 'Shipped', 29),
#  ('Signal Gift Stores', 112, 10278, 'Shipped', 31),
#  ('Signal Gift Stores', 112, 10278, 'Shipped', 31),
#  ('Signal Gift Stores', 112, 10278, 'Shipped', 34),
#  ('Signal Gift Stores', 112, 10278, 'Shipped', 35),
#  ('Signal Gift Stores', 112, 10278, 'Shipped', 39),
#  ('Signal Gift Stores', 112, 10278, 'Shipped', 42),
#  ('Signal Gift Stores', 112, 10346, 'Shipped', 22),
#  ('Signal Gift Stores', 112, 10346, 'Shipped', 24),
#  ('Signal Gift Stores', 112, 10346, 'Shipped', 24),
#  ('Signal Gift Stores', 112, 10346, 'Shipped', 25),
#  ('Signal Gift Stores', 112, 10346, 'Shipped', 26),
#  ('Signal Gift Stores', 112, 10346, 'Shipped', 42),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 22),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 24),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 24),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 29),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 29),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 29),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 29),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 34),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 35),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 39),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 43),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 46),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 46),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 47),
#  ('Australian Collectors, Co.', 114, 10120, 'Shipped', 49),
#  ('Australian Collectors, Co.', 114, 10125, 'Shipped', 32),
#  ('Australian Collectors, Co.', 114, 10125, 'Shipped', 34),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 20),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 21),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 23),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 25),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 26),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 28),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 29),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 32),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 34),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 37),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 38),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 41),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 47),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 47),
#  ('Australian Collectors, Co.', 114, 10223, 'Shipped', 49),
#  ('Australian Collectors, Co.', 114, 10342, 'Shipped', 22),
#  ('Australian Collectors, Co.', 114, 10342, 'Shipped', 25),
#  ('Australian Collectors, Co.', 114, 10342, 'Shipped', 26),
#  ('Australian Collectors, Co.', 114, 10342, 'Shipped', 30),
#  ('Australian Collectors, Co.', 114, 10342, 'Shipped', 38),
#  ('Australian Collectors, Co.', 114, 10342, 'Shipped', 39),
#  ('Australian Collectors, Co.', 114, 10342, 'Shipped', 40),
#  ('Australian Collectors, Co.', 114, 10342, 'Shipped', 42),
#  ('Australian Collectors, Co.', 114, 10342, 'Shipped', 48),
#  ('Australian Collectors, Co.', 114, 10342, 'Shipped', 55),
#  ('Australian Collectors, Co.', 114, 10342, 'Shipped', 55),
#  ('Australian Collectors, Co.', 114, 10347, 'Shipped', 21),
#  ('Australian Collectors, Co.', 114, 10347, 'Shipped', 21),
#  ('Australian Collectors, Co.', 114, 10347, 'Shipped', 26),
#  ('Australian Collectors, Co.', 114, 10347, 'Shipped', 27),
#  ('Australian Collectors, Co.', 114, 10347, 'Shipped', 29),
#  ('Australian Collectors, Co.', 114, 10347, 'Shipped', 30),
#  ('Australian Collectors, Co.', 114, 10347, 'Shipped', 34),
#  ('Australian Collectors, Co.', 114, 10347, 'Shipped', 42),
#  ('Australian Collectors, Co.', 114, 10347, 'Shipped', 45),
#  ('Australian Collectors, Co.', 114, 10347, 'Shipped', 45),
#  ('Australian Collectors, Co.', 114, 10347, 'Shipped', 48),
#  ('Australian Collectors, Co.', 114, 10347, 'Shipped', 50),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 21),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 22),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 23),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 25),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 27),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 28),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 30),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 31),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 32),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 35),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 36),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 37),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 38),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 39),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 41),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 43),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 45),
#  ('La Rochelle Gifts', 119, 10275, 'Shipped', 48),
#  ('La Rochelle Gifts', 119, 10315, 'Shipped', 24),
#  ('La Rochelle Gifts', 119, 10315, 'Shipped', 31),
#  ('La Rochelle Gifts', 119, 10315, 'Shipped', 35),
#  ('La Rochelle Gifts', 119, 10315, 'Shipped', 36),
#  ('La Rochelle Gifts', 119, 10315, 'Shipped', 37),
#  ('La Rochelle Gifts', 119, 10315, 'Shipped', 40),
#  ('La Rochelle Gifts', 119, 10315, 'Shipped', 41),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 20),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 21),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 23),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 25),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 33),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 37),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 37),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 41),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 43),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 44),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 44),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 45),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 49),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 49),
#  ('La Rochelle Gifts', 119, 10375, 'Shipped', 49),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 11),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 18),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 19),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 28),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 28),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 31),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 33),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 38),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 38),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 38),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 41),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 49),
#  ('La Rochelle Gifts', 119, 10425, 'In Process', 55),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 22),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 25),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 25),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 26),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 27),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 27),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 31),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 35),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 35),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 36),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 36),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 41),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 42),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 42),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 45),
#  ('Baane Mini Imports', 121, 10103, 'Shipped', 46),
#  ('Baane Mini Imports', 121, 10158, 'Shipped', 22),
#  ('Baane Mini Imports', 121, 10309, 'Shipped', 21),
#  ('Baane Mini Imports', 121, 10309, 'Shipped', 24),
#  ('Baane Mini Imports', 121, 10309, 'Shipped', 26),
#  ('Baane Mini Imports', 121, 10309, 'Shipped', 28),
#  ('Baane Mini Imports', 121, 10309, 'Shipped', 41),
#  ('Baane Mini Imports', 121, 10309, 'Shipped', 50),
#  ('Baane Mini Imports', 121, 10325, 'Shipped', 24),
#  ('Baane Mini Imports', 121, 10325, 'Shipped', 24),
#  ('Baane Mini Imports', 121, 10325, 'Shipped', 28),
#  ('Baane Mini Imports', 121, 10325, 'Shipped', 38),
#  ('Baane Mini Imports', 121, 10325, 'Shipped', 38),
#  ('Baane Mini Imports', 121, 10325, 'Shipped', 42),
#  ('Baane Mini Imports', 121, 10325, 'Shipped', 44),
#  ('Baane Mini Imports', 121, 10325, 'Shipped', 44),
#  ('Baane Mini Imports', 121, 10325, 'Shipped', 47),
#  ('Mini Gifts Distributors Ltd.', 124, 10113, 'Shipped', 21),
#  ('Mini Gifts Distributors Ltd.', 124, 10113, 'Shipped', 23),
#  ('Mini Gifts Distributors Ltd.', 124, 10113, 'Shipped', 49),
#  ('Mini Gifts Distributors Ltd.', 124, 10113, 'Shipped', 50),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 20),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 23),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 24),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 27),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 29),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 29),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 30),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 31),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 33),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 42),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 42),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 44),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 45),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 45),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 47),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 48),
#  ('Mini Gifts Distributors Ltd.', 124, 10135, 'Shipped', 48),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 21),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 22),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 24),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 24),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 33),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 33),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 33),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 38),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 39),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 41),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 42),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 42),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 43),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 46),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 47),
#  ('Mini Gifts Distributors Ltd.', 124, 10142, 'Shipped', 49),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 20),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 20),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 21),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 23),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 25),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 31),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 32),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 33),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 33),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 36),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 36),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 38),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 39),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 44),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 44),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 47),
#  ('Mini Gifts Distributors Ltd.', 124, 10182, 'Shipped', 49),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 22),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 23),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 25),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 25),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 26),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 28),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 30),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 33),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 36),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 39),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 41),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 48),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 50),
#  ('Mini Gifts Distributors Ltd.', 124, 10229, 'Shipped', 50),
#  ('Mini Gifts Distributors Ltd.', 124, 10271, 'Shipped', 20),
#  ('Mini Gifts Distributors Ltd.', 124, 10271, 'Shipped', 22),
#  ('Mini Gifts Distributors Ltd.', 124, 10271, 'Shipped', 25),
#  ('Mini Gifts Distributors Ltd.', 124, 10271, 'Shipped', 31),
#  ('Mini Gifts Distributors Ltd.', 124, 10271, 'Shipped', 34),
#  ('Mini Gifts Distributors Ltd.', 124, 10271, 'Shipped', 35),
#  ('Mini Gifts Distributors Ltd.', 124, 10271, 'Shipped', 38),
#  ('Mini Gifts Distributors Ltd.', 124, 10271, 'Shipped', 43),
#  ('Mini Gifts Distributors Ltd.', 124, 10271, 'Shipped', 45),
#  ('Mini Gifts Distributors Ltd.', 124, 10271, 'Shipped', 50),
#  ('Mini Gifts Distributors Ltd.', 124, 10271, 'Shipped', 50),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 23),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 24),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 27),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 29),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 31),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 36),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 36),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 37),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 38),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 39),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 41),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 43),
#  ('Mini Gifts Distributors Ltd.', 124, 10282, 'Shipped', 43),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 23),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 25),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 25),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 30),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 31),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 31),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 32),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 33),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 35),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 37),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 38),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 39),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 39),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 43),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 44),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 48),
#  ('Mini Gifts Distributors Ltd.', 124, 10312, 'Shipped', 48),
#  ('Mini Gifts Distributors Ltd.', 124, 10335, 'Shipped', 33),
#  ('Mini Gifts Distributors Ltd.', 124, 10335, 'Shipped', 40),
#  ('Mini Gifts Distributors Ltd.', 124, 10335, 'Shipped', 44),
#  ('Mini Gifts Distributors Ltd.', 124, 10357, 'Shipped', 25),
#  ('Mini Gifts Distributors Ltd.', 124, 10357, 'Shipped', 28),
#  ('Mini Gifts Distributors Ltd.', 124, 10357, 'Shipped', 32),
#  ('Mini Gifts Distributors Ltd.', 124, 10357, 'Shipped', 39),
#  ('Mini Gifts Distributors Ltd.', 124, 10357, 'Shipped', 41),
#  ('Mini Gifts Distributors Ltd.', 124, 10357, 'Shipped', 41),
#  ('Mini Gifts Distributors Ltd.', 124, 10357, 'Shipped', 43),
#  ('Mini Gifts Distributors Ltd.', 124, 10357, 'Shipped', 44),
#  ('Mini Gifts Distributors Ltd.', 124, 10357, 'Shipped', 49),
#  ('Mini Gifts Distributors Ltd.', 124, 10357, 'Shipped', 49),
#  ('Mini Gifts Distributors Ltd.', 124, 10368, 'Shipped', 20),
#  ('Mini Gifts Distributors Ltd.', 124, 10368, 'Shipped', 31),
#  ('Mini Gifts Distributors Ltd.', 124, 10368, 'Shipped', 40),
#  ('Mini Gifts Distributors Ltd.', 124, 10368, 'Shipped', 46),
#  ('Mini Gifts Distributors Ltd.', 124, 10368, 'Shipped', 46),
#  ('Mini Gifts Distributors Ltd.', 124, 10371, 'Shipped', 20),
#  ('Mini Gifts Distributors Ltd.', 124, 10371, 'Shipped', 20),
#  ('Mini Gifts Distributors Ltd.', 124, 10371, 'Shipped', 25),
#  ('Mini Gifts Distributors Ltd.', 124, 10371, 'Shipped', 25),
#  ('Mini Gifts Distributors Ltd.', 124, 10371, 'Shipped', 26),
#  ('Mini Gifts Distributors Ltd.', 124, 10371, 'Shipped', 28),
#  ('Mini Gifts Distributors Ltd.', 124, 10371, 'Shipped', 30),
#  ('Mini Gifts Distributors Ltd.', 124, 10371, 'Shipped', 32),
#  ('Mini Gifts Distributors Ltd.', 124, 10371, 'Shipped', 34),
#  ('Mini Gifts Distributors Ltd.', 124, 10371, 'Shipped', 45),
#  ('Mini Gifts Distributors Ltd.', 124, 10371, 'Shipped', 48),
#  ('Mini Gifts Distributors Ltd.', 124, 10371, 'Shipped', 49),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 20),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 25),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 26),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 32),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 33),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 34),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 34),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 34),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 37),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 39),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 39),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 48),
#  ('Mini Gifts Distributors Ltd.', 124, 10382, 'Shipped', 50),
#  ('Mini Gifts Distributors Ltd.', 124, 10385, 'Shipped', 25),
#  ('Mini Gifts Distributors Ltd.', 124, 10385, 'Shipped', 37),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 22),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 26),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 30),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 31),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 34),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 35),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 36),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 36),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 37),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 40),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 41),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 45),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 45),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 46),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 49),
#  ('Mini Gifts Distributors Ltd.', 124, 10390, 'Shipped', 50),
#  ('Mini Gifts Distributors Ltd.', 124, 10396, 'Shipped', 24),
#  ('Mini Gifts Distributors Ltd.', 124, 10396, 'Shipped', 27),
#  ('Mini Gifts Distributors Ltd.', 124, 10396, 'Shipped', 33),
#  ('Mini Gifts Distributors Ltd.', 124, 10396, 'Shipped', 33),
#  ('Mini Gifts Distributors Ltd.', 124, 10396, 'Shipped', 37),
#  ('Mini Gifts Distributors Ltd.', 124, 10396, 'Shipped', 39),
#  ('Mini Gifts Distributors Ltd.', 124, 10396, 'Shipped', 45),
#  ('Mini Gifts Distributors Ltd.', 124, 10396, 'Shipped', 49),
#  ('Mini Gifts Distributors Ltd.', 124, 10421, 'In Process', 35),
#  ('Mini Gifts Distributors Ltd.', 124, 10421, 'In Process', 40),
#  ('Blauer See Auto, Co.', 128, 10101, 'Shipped', 25),
#  ('Blauer See Auto, Co.', 128, 10101, 'Shipped', 26),
#  ('Blauer See Auto, Co.', 128, 10101, 'Shipped', 45),
#  ('Blauer See Auto, Co.', 128, 10101, 'Shipped', 46),
#  ('Blauer See Auto, Co.', 128, 10230, 'Shipped', 34),
#  ('Blauer See Auto, Co.', 128, 10230, 'Shipped', 36),
#  ('Blauer See Auto, Co.', 128, 10230, 'Shipped', 42),
#  ('Blauer See Auto, Co.', 128, 10230, 'Shipped', 43),
#  ('Blauer See Auto, Co.', 128, 10230, 'Shipped', 43),
#  ('Blauer See Auto, Co.', 128, 10230, 'Shipped', 45),
#  ('Blauer See Auto, Co.', 128, 10230, 'Shipped', 46),
#  ('Blauer See Auto, Co.', 128, 10230, 'Shipped', 49),
#  ('Blauer See Auto, Co.', 128, 10300, 'Shipped', 22),
#  ('Blauer See Auto, Co.', 128, 10300, 'Shipped', 23),
#  ('Blauer See Auto, Co.', 128, 10300, 'Shipped', 23),
#  ('Blauer See Auto, Co.', 128, 10300, 'Shipped', 29),
#  ('Blauer See Auto, Co.', 128, 10300, 'Shipped', 31),
#  ('Blauer See Auto, Co.', 128, 10300, 'Shipped', 33),
#  ('Blauer See Auto, Co.', 128, 10300, 'Shipped', 41),
#  ('Blauer See Auto, Co.', 128, 10300, 'Shipped', 49),
#  ('Blauer See Auto, Co.', 128, 10323, 'Shipped', 33),
#  ('Blauer See Auto, Co.', 128, 10323, 'Shipped', 47),
#  ('Mini Wheels Co.', 129, 10111, 'Shipped', 26),
#  ('Mini Wheels Co.', 129, 10111, 'Shipped', 28),
#  ('Mini Wheels Co.', 129, 10111, 'Shipped', 33),
#  ('Mini Wheels Co.', 129, 10111, 'Shipped', 39),
#  ('Mini Wheels Co.', 129, 10111, 'Shipped', 43),
#  ('Mini Wheels Co.', 129, 10111, 'Shipped', 48),
#  ('Mini Wheels Co.', 129, 10201, 'Shipped', 22),
#  ('Mini Wheels Co.', 129, 10201, 'Shipped', 24),
#  ('Mini Wheels Co.', 129, 10201, 'Shipped', 25),
#  ('Mini Wheels Co.', 129, 10201, 'Shipped', 25),
#  ('Mini Wheels Co.', 129, 10201, 'Shipped', 30),
#  ('Mini Wheels Co.', 129, 10201, 'Shipped', 39),
#  ('Mini Wheels Co.', 129, 10201, 'Shipped', 49),
#  ('Mini Wheels Co.', 129, 10333, 'Shipped', 24),
#  ('Mini Wheels Co.', 129, 10333, 'Shipped', 26),
#  ('Mini Wheels Co.', 129, 10333, 'Shipped', 29),
#  ('Mini Wheels Co.', 129, 10333, 'Shipped', 31),
#  ('Mini Wheels Co.', 129, 10333, 'Shipped', 33),
#  ('Mini Wheels Co.', 129, 10333, 'Shipped', 33),
#  ('Mini Wheels Co.', 129, 10333, 'Shipped', 39),
#  ('Mini Wheels Co.', 129, 10333, 'Shipped', 46),
#  ('Land of Toys Inc.', 131, 10107, 'Shipped', 20),
#  ('Land of Toys Inc.', 131, 10107, 'Shipped', 21),
#  ('Land of Toys Inc.', 131, 10107, 'Shipped', 25),
#  ('Land of Toys Inc.', 131, 10107, 'Shipped', 27),
#  ('Land of Toys Inc.', 131, 10107, 'Shipped', 29),
#  ('Land of Toys Inc.', 131, 10107, 'Shipped', 30),
#  ('Land of Toys Inc.', 131, 10107, 'Shipped', 38),
#  ('Land of Toys Inc.', 131, 10107, 'Shipped', 39),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 20),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 21),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 23),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 23),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 30),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 30),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 32),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 32),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 35),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 36),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 40),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 42),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 42),
#  ('Land of Toys Inc.', 131, 10248, 'Cancelled', 48),
#  ('Land of Toys Inc.', 131, 10292, 'Shipped', 21),
#  ('Land of Toys Inc.', 131, 10292, 'Shipped', 21),
#  ('Land of Toys Inc.', 131, 10292, 'Shipped', 26),
#  ('Land of Toys Inc.', 131, 10292, 'Shipped', 27),
#  ('Land of Toys Inc.', 131, 10292, 'Shipped', 31),
#  ('Land of Toys Inc.', 131, 10292, 'Shipped', 35),
#  ('Land of Toys Inc.', 131, 10292, 'Shipped', 39),
#  ('Land of Toys Inc.', 131, 10292, 'Shipped', 40),
#  ('Land of Toys Inc.', 131, 10292, 'Shipped', 41),
#  ('Land of Toys Inc.', 131, 10292, 'Shipped', 41),
#  ('Land of Toys Inc.', 131, 10292, 'Shipped', 44),
#  ('Land of Toys Inc.', 131, 10292, 'Shipped', 50),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 20),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 24),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 26),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 29),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 30),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 33),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 37),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 38),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 38),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 39),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 41),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 42),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 44),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 45),
#  ('Land of Toys Inc.', 131, 10329, 'Shipped', 46),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 23),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 24),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 26),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 29),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 33),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 34),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 35),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 35),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 38),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 44),
#  ('Euro+ Shopping Channel', 141, 10104, 'Shipped', 49),
#  ('Euro+ Shopping Channel', 141, 10128, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10128, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10128, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10128, 'Shipped', 43),
#  ('Euro+ Shopping Channel', 141, 10133, 'Shipped', 23),
#  ('Euro+ Shopping Channel', 141, 10133, 'Shipped', 24),
#  ('Euro+ Shopping Channel', 141, 10133, 'Shipped', 27),
#  ('Euro+ Shopping Channel', 141, 10133, 'Shipped', 27),
#  ('Euro+ Shopping Channel', 141, 10133, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10133, 'Shipped', 46),
#  ('Euro+ Shopping Channel', 141, 10133, 'Shipped', 49),
#  ('Euro+ Shopping Channel', 141, 10133, 'Shipped', 49),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 20),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 20),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 22),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 29),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 31),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 31),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 31),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 40),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 42),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 43),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 49),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 50),
#  ('Euro+ Shopping Channel', 141, 10153, 'Shipped', 50),
#  ('Euro+ Shopping Channel', 141, 10156, 'Shipped', 20),
#  ('Euro+ Shopping Channel', 141, 10156, 'Shipped', 48),
#  ('Euro+ Shopping Channel', 141, 10190, 'Shipped', 40),
#  ('Euro+ Shopping Channel', 141, 10190, 'Shipped', 42),
#  ('Euro+ Shopping Channel', 141, 10190, 'Shipped', 42),
#  ('Euro+ Shopping Channel', 141, 10190, 'Shipped', 46),
#  ('Euro+ Shopping Channel', 141, 10203, 'Shipped', 20),
#  ('Euro+ Shopping Channel', 141, 10203, 'Shipped', 20),
#  ('Euro+ Shopping Channel', 141, 10203, 'Shipped', 21),
#  ('Euro+ Shopping Channel', 141, 10203, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10203, 'Shipped', 33),
#  ('Euro+ Shopping Channel', 141, 10203, 'Shipped', 34),
#  ('Euro+ Shopping Channel', 141, 10203, 'Shipped', 44),
#  ('Euro+ Shopping Channel', 141, 10203, 'Shipped', 45),
#  ('Euro+ Shopping Channel', 141, 10203, 'Shipped', 47),
#  ('Euro+ Shopping Channel', 141, 10203, 'Shipped', 47),
#  ('Euro+ Shopping Channel', 141, 10203, 'Shipped', 48),
#  ('Euro+ Shopping Channel', 141, 10205, 'Shipped', 24),
#  ('Euro+ Shopping Channel', 141, 10205, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10205, 'Shipped', 36),
#  ('Euro+ Shopping Channel', 141, 10205, 'Shipped', 40),
#  ('Euro+ Shopping Channel', 141, 10205, 'Shipped', 48),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 20),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 27),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 29),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 33),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 34),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 38),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 39),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 40),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 40),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 45),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 45),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 45),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 46),
#  ('Euro+ Shopping Channel', 141, 10212, 'Shipped', 49),
#  ('Euro+ Shopping Channel', 141, 10244, 'Shipped', 20),
#  ('Euro+ Shopping Channel', 141, 10244, 'Shipped', 24),
#  ('Euro+ Shopping Channel', 141, 10244, 'Shipped', 29),
#  ('Euro+ Shopping Channel', 141, 10244, 'Shipped', 30),
#  ('Euro+ Shopping Channel', 141, 10244, 'Shipped', 36),
#  ('Euro+ Shopping Channel', 141, 10244, 'Shipped', 39),
#  ('Euro+ Shopping Channel', 141, 10244, 'Shipped', 40),
#  ('Euro+ Shopping Channel', 141, 10244, 'Shipped', 40),
#  ('Euro+ Shopping Channel', 141, 10244, 'Shipped', 43),
#  ('Euro+ Shopping Channel', 141, 10246, 'Shipped', 22),
#  ('Euro+ Shopping Channel', 141, 10246, 'Shipped', 22),
#  ('Euro+ Shopping Channel', 141, 10246, 'Shipped', 29),
#  ('Euro+ Shopping Channel', 141, 10246, 'Shipped', 30),
#  ('Euro+ Shopping Channel', 141, 10246, 'Shipped', 35),
#  ('Euro+ Shopping Channel', 141, 10246, 'Shipped', 36),
#  ('Euro+ Shopping Channel', 141, 10246, 'Shipped', 40),
#  ('Euro+ Shopping Channel', 141, 10246, 'Shipped', 44),
#  ('Euro+ Shopping Channel', 141, 10246, 'Shipped', 46),
#  ('Euro+ Shopping Channel', 141, 10246, 'Shipped', 46),
#  ('Euro+ Shopping Channel', 141, 10246, 'Shipped', 49),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 21),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 24),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 27),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 32),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 33),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 34),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 34),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 35),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 40),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 40),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 44),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 46),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 48),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 49),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 49),
#  ('Euro+ Shopping Channel', 141, 10262, 'Cancelled', 49),
#  ('Euro+ Shopping Channel', 141, 10279, 'Shipped', 26),
#  ('Euro+ Shopping Channel', 141, 10279, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10279, 'Shipped', 33),
#  ('Euro+ Shopping Channel', 141, 10279, 'Shipped', 48),
#  ('Euro+ Shopping Channel', 141, 10279, 'Shipped', 48),
#  ('Euro+ Shopping Channel', 141, 10279, 'Shipped', 49),
#  ('Euro+ Shopping Channel', 141, 10311, 'Shipped', 25),
#  ('Euro+ Shopping Channel', 141, 10311, 'Shipped', 25),
#  ('Euro+ Shopping Channel', 141, 10311, 'Shipped', 26),
#  ('Euro+ Shopping Channel', 141, 10311, 'Shipped', 28),
#  ('Euro+ Shopping Channel', 141, 10311, 'Shipped', 29),
#  ('Euro+ Shopping Channel', 141, 10311, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10311, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10311, 'Shipped', 43),
#  ('Euro+ Shopping Channel', 141, 10311, 'Shipped', 43),
#  ('Euro+ Shopping Channel', 141, 10311, 'Shipped', 45),
#  ('Euro+ Shopping Channel', 141, 10311, 'Shipped', 46),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 20),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 25),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 25),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 26),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 27),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 28),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 29),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 30),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 30),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 31),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 31),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 34),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 43),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 44),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 44),
#  ('Euro+ Shopping Channel', 141, 10350, 'Shipped', 46),
#  ('Euro+ Shopping Channel', 141, 10355, 'Shipped', 23),
#  ('Euro+ Shopping Channel', 141, 10355, 'Shipped', 25),
#  ('Euro+ Shopping Channel', 141, 10355, 'Shipped', 28),
#  ('Euro+ Shopping Channel', 141, 10355, 'Shipped', 31),
#  ('Euro+ Shopping Channel', 141, 10355, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10355, 'Shipped', 36),
#  ('Euro+ Shopping Channel', 141, 10355, 'Shipped', 38),
#  ('Euro+ Shopping Channel', 141, 10355, 'Shipped', 40),
#  ('Euro+ Shopping Channel', 141, 10355, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10355, 'Shipped', 44),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 20),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 20),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 25),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 27),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 30),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 36),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 36),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 42),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 44),
#  ('Euro+ Shopping Channel', 141, 10358, 'Shipped', 49),
#  ('Euro+ Shopping Channel', 141, 10378, 'Shipped', 22),
#  ('Euro+ Shopping Channel', 141, 10378, 'Shipped', 28),
#  ('Euro+ Shopping Channel', 141, 10378, 'Shipped', 33),
#  ('Euro+ Shopping Channel', 141, 10378, 'Shipped', 34),
#  ('Euro+ Shopping Channel', 141, 10378, 'Shipped', 40),
#  ('Euro+ Shopping Channel', 141, 10378, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10378, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10378, 'Shipped', 43),
#  ('Euro+ Shopping Channel', 141, 10378, 'Shipped', 46),
#  ('Euro+ Shopping Channel', 141, 10378, 'Shipped', 49),
#  ('Euro+ Shopping Channel', 141, 10379, 'Shipped', 27),
#  ('Euro+ Shopping Channel', 141, 10379, 'Shipped', 29),
#  ('Euro+ Shopping Channel', 141, 10379, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10379, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10379, 'Shipped', 39),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 21),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 24),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 27),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 27),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 34),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 34),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 36),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 40),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 43),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 44),
#  ('Euro+ Shopping Channel', 141, 10380, 'Shipped', 44),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 21),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 22),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 24),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 26),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 27),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 28),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 29),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 32),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 38),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 38),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 40),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 44),
#  ('Euro+ Shopping Channel', 141, 10383, 'Shipped', 47),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 21),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 22),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 25),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 29),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 30),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 32),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 33),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 35),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 37),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 37),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 37),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 39),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 41),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 43),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 44),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 45),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 50),
#  ('Euro+ Shopping Channel', 141, 10386, 'Resolved', 50),
#  ('Euro+ Shopping Channel', 141, 10394, 'Shipped', 22),
#  ('Euro+ Shopping Channel', 141, 10394, 'Shipped', 30),
#  ('Euro+ Shopping Channel', 141, 10394, 'Shipped', 31),
#  ('Euro+ Shopping Channel', 141, 10394, 'Shipped', 36),
#  ('Euro+ Shopping Channel', 141, 10394, 'Shipped', 37),
#  ('Euro+ Shopping Channel', 141, 10394, 'Shipped', 37),
#  ('Euro+ Shopping Channel', 141, 10394, 'Shipped', 46),
#  ('Euro+ Shopping Channel', 141, 10412, 'Shipped', 19),
#  ('Euro+ Shopping Channel', 141, 10412, 'Shipped', 21),
#  ('Euro+ Shopping Channel', 141, 10412, 'Shipped', 26),
#  ('Euro+ Shopping Channel', 141, 10412, 'Shipped', 30),
#  ('Euro+ Shopping Channel', 141, 10412, 'Shipped', 31),
#  ('Euro+ Shopping Channel', 141, 10412, 'Shipped', 41),
#  ('Euro+ Shopping Channel', 141, 10412, 'Shipped', 47),
#  ('Euro+ Shopping Channel', 141, 10412, 'Shipped', 54),
#  ('Euro+ Shopping Channel', 141, 10412, 'Shipped', 56),
#  ('Euro+ Shopping Channel', 141, 10412, 'Shipped', 60),
#  ('Euro+ Shopping Channel', 141, 10412, 'Shipped', 70),
#  ('Euro+ Shopping Channel', 141, 10417, 'Disputed', 21),
#  ('Euro+ Shopping Channel', 141, 10417, 'Disputed', 35),
#  ('Euro+ Shopping Channel', 141, 10417, 'Disputed', 36),
#  ('Euro+ Shopping Channel', 141, 10417, 'Disputed', 45),
#  ('Euro+ Shopping Channel', 141, 10417, 'Disputed', 56),
#  ('Euro+ Shopping Channel', 141, 10417, 'Disputed', 66),
#  ('Euro+ Shopping Channel', 141, 10424, 'In Process', 26),
#  ('Euro+ Shopping Channel', 141, 10424, 'In Process', 44),
#  ('Euro+ Shopping Channel', 141, 10424, 'In Process', 46),
#  ('Euro+ Shopping Channel', 141, 10424, 'In Process', 49),
#  ('Euro+ Shopping Channel', 141, 10424, 'In Process', 50),
#  ('Euro+ Shopping Channel', 141, 10424, 'In Process', 54),
#  ('Volvo Model Replicas, Co', 144, 10112, 'Shipped', 23),
#  ('Volvo Model Replicas, Co', 144, 10112, 'Shipped', 29),
#  ('Volvo Model Replicas, Co', 144, 10320, 'Shipped', 25),
#  ('Volvo Model Replicas, Co', 144, 10320, 'Shipped', 26),
#  ('Volvo Model Replicas, Co', 144, 10320, 'Shipped', 31),
#  ('Volvo Model Replicas, Co', 144, 10320, 'Shipped', 35),
#  ('Volvo Model Replicas, Co', 144, 10320, 'Shipped', 38),
#  ('Volvo Model Replicas, Co', 144, 10326, 'Shipped', 20),
#  ('Volvo Model Replicas, Co', 144, 10326, 'Shipped', 32),
#  ('Volvo Model Replicas, Co', 144, 10326, 'Shipped', 39),
#  ('Volvo Model Replicas, Co', 144, 10326, 'Shipped', 41),
#  ('Volvo Model Replicas, Co', 144, 10326, 'Shipped', 41),
#  ('Volvo Model Replicas, Co', 144, 10326, 'Shipped', 50),
#  ('Volvo Model Replicas, Co', 144, 10334, 'On Hold', 20),
#  ('Volvo Model Replicas, Co', 144, 10334, 'On Hold', 26),
#  ('Volvo Model Replicas, Co', 144, 10334, 'On Hold', 34),
#  ('Volvo Model Replicas, Co', 144, 10334, 'On Hold', 42),
#  ('Volvo Model Replicas, Co', 144, 10334, 'On Hold', 46),
#  ('Volvo Model Replicas, Co', 144, 10334, 'On Hold', 49),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 22),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 22),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 25),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 29),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 29),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 31),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 38),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 39),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 41),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 41),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 41),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 43),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 44),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 50),
#  ('Danish Wholesale Imports', 145, 10105, 'Shipped', 50),
#  ('Danish Wholesale Imports', 145, 10238, 'Shipped', 20),
#  ('Danish Wholesale Imports', 145, 10238, 'Shipped', 22),
#  ('Danish Wholesale Imports', 145, 10238, 'Shipped', 28),
#  ('Danish Wholesale Imports', 145, 10238, 'Shipped', 29),
#  ('Danish Wholesale Imports', 145, 10238, 'Shipped', 41),
#  ('Danish Wholesale Imports', 145, 10238, 'Shipped', 44),
#  ('Danish Wholesale Imports', 145, 10238, 'Shipped', 47),
#  ('Danish Wholesale Imports', 145, 10238, 'Shipped', 49),
#  ('Danish Wholesale Imports', 145, 10256, 'Shipped', 29),
#  ('Danish Wholesale Imports', 145, 10256, 'Shipped', 34),
#  ('Danish Wholesale Imports', 145, 10327, 'Resolved', 20),
#  ('Danish Wholesale Imports', 145, 10327, 'Resolved', 21),
#  ('Danish Wholesale Imports', 145, 10327, 'Resolved', 25),
#  ('Danish Wholesale Imports', 145, 10327, 'Resolved', 25),
#  ('Danish Wholesale Imports', 145, 10327, 'Resolved', 37),
#  ('Danish Wholesale Imports', 145, 10327, 'Resolved', 37),
#  ('Danish Wholesale Imports', 145, 10327, 'Resolved', 43),
#  ('Danish Wholesale Imports', 145, 10327, 'Resolved', 45),
#  ('Danish Wholesale Imports', 145, 10406, 'Disputed', 48),
#  ('Danish Wholesale Imports', 145, 10406, 'Disputed', 61),
#  ('Danish Wholesale Imports', 145, 10406, 'Disputed', 65),
#  ('Saveley & Henriot, Co.', 146, 10194, 'Shipped', 21),
#  ('Saveley & Henriot, Co.', 146, 10194, 'Shipped', 26),
#  ('Saveley & Henriot, Co.', 146, 10194, 'Shipped', 26),
#  ('Saveley & Henriot, Co.', 146, 10194, 'Shipped', 32),
#  ('Saveley & Henriot, Co.', 146, 10194, 'Shipped', 37),
#  ('Saveley & Henriot, Co.', 146, 10194, 'Shipped', 38),
#  ('Saveley & Henriot, Co.', 146, 10194, 'Shipped', 39),
#  ('Saveley & Henriot, Co.', 146, 10194, 'Shipped', 41),
#  ('Saveley & Henriot, Co.', 146, 10194, 'Shipped', 42),
#  ('Saveley & Henriot, Co.', 146, 10194, 'Shipped', 45),
#  ('Saveley & Henriot, Co.', 146, 10194, 'Shipped', 49),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 20),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 20),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 24),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 26),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 30),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 33),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 35),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 37),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 38),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 40),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 42),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 45),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 46),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 46),
#  ('Saveley & Henriot, Co.', 146, 10208, 'Shipped', 48),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 24),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 25),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 26),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 27),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 28),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 29),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 31),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 33),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 33),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 34),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 37),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 40),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 42),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 46),
#  ('Saveley & Henriot, Co.', 146, 10227, 'Shipped', 47),
#  ('Dragon Souveniers, Ltd.', 148, 10117, 'Shipped', 21),
#  ('Dragon Souveniers, Ltd.', 148, 10117, 'Shipped', 21),
#  ('Dragon Souveniers, Ltd.', 148, 10117, 'Shipped', 22),
#  ('Dragon Souveniers, Ltd.', 148, 10117, 'Shipped', 23),
#  ('Dragon Souveniers, Ltd.', 148, 10117, 'Shipped', 26),
#  ('Dragon Souveniers, Ltd.', 148, 10117, 'Shipped', 33),
#  ('Dragon Souveniers, Ltd.', 148, 10117, 'Shipped', 38),
#  ('Dragon Souveniers, Ltd.', 148, 10117, 'Shipped', 39),
#  ('Dragon Souveniers, Ltd.', 148, 10117, 'Shipped', 41),
#  ('Dragon Souveniers, Ltd.', 148, 10117, 'Shipped', 43),
#  ('Dragon Souveniers, Ltd.', 148, 10117, 'Shipped', 45),
#  ('Dragon Souveniers, Ltd.', 148, 10117, 'Shipped', 50),
#  ('Dragon Souveniers, Ltd.', 148, 10150, 'Shipped', 20),
#  ('Dragon Souveniers, Ltd.', 148, 10150, 'Shipped', 20),
#  ('Dragon Souveniers, Ltd.', 148, 10150, 'Shipped', 26),
#  ('Dragon Souveniers, Ltd.', 148, 10150, 'Shipped', 30),
#  ('Dragon Souveniers, Ltd.', 148, 10150, 'Shipped', 30),
#  ('Dragon Souveniers, Ltd.', 148, 10150, 'Shipped', 30),
#  ('Dragon Souveniers, Ltd.', 148, 10150, 'Shipped', 34),
#  ('Dragon Souveniers, Ltd.', 148, 10150, 'Shipped', 45),
#  ('Dragon Souveniers, Ltd.', 148, 10150, 'Shipped', 47),
#  ('Dragon Souveniers, Ltd.', 148, 10150, 'Shipped', 49),
#  ('Dragon Souveniers, Ltd.', 148, 10150, 'Shipped', 49),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 24),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 25),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 27),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 27),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 28),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 29),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 31),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 32),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 34),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 38),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 44),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 44),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 46),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 47),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 48),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 48),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 48),
#  ('Dragon Souveniers, Ltd.', 148, 10165, 'Shipped', 50),
#  ('Dragon Souveniers, Ltd.', 148, 10277, 'Shipped', 28),
#  ('Dragon Souveniers, Ltd.', 148, 10387, 'Shipped', 44),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 20),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 20),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 22),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 24),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 25),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 29),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 39),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 42),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 45),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 45),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 45),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 46),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 46),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 46),
#  ('Muscle Machine Inc', 151, 10127, 'Shipped', 46),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 20),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 23),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 26),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 27),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 29),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 33),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 35),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 38),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 39),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 40),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 40),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 42),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 42),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 45),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 45),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 47),
#  ('Muscle Machine Inc', 151, 10204, 'Shipped', 48),
#  ('Muscle Machine Inc', 151, 10267, 'Shipped', 36),
#  ('Muscle Machine Inc', 151, 10267, 'Shipped', 38),
#  ('Muscle Machine Inc', 151, 10267, 'Shipped', 40),
#  ('Muscle Machine Inc', 151, 10267, 'Shipped', 43),
#  ('Muscle Machine Inc', 151, 10267, 'Shipped', 43),
#  ('Muscle Machine Inc', 151, 10267, 'Shipped', 44),
#  ('Muscle Machine Inc', 151, 10349, 'Shipped', 23),
#  ('Muscle Machine Inc', 151, 10349, 'Shipped', 26),
#  ('Muscle Machine Inc', 151, 10349, 'Shipped', 33),
#  ('Muscle Machine Inc', 151, 10349, 'Shipped', 34),
#  ('Muscle Machine Inc', 151, 10349, 'Shipped', 36),
#  ('Muscle Machine Inc', 151, 10349, 'Shipped', 38),
#  ('Muscle Machine Inc', 151, 10349, 'Shipped', 38),
#  ('Muscle Machine Inc', 151, 10349, 'Shipped', 48),
#  ('Muscle Machine Inc', 151, 10349, 'Shipped', 48),
#  ('Muscle Machine Inc', 151, 10349, 'Shipped', 48),
#  ('Diecast Classics Inc.', 157, 10272, 'Shipped', 25),
#  ('Diecast Classics Inc.', 157, 10272, 'Shipped', 27),
#  ('Diecast Classics Inc.', 157, 10272, 'Shipped', 35),
#  ('Diecast Classics Inc.', 157, 10272, 'Shipped', 39),
#  ('Diecast Classics Inc.', 157, 10272, 'Shipped', 43),
#  ('Diecast Classics Inc.', 157, 10272, 'Shipped', 45),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 20),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 25),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 25),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 25),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 25),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 27),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 29),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 29),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 31),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 36),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 41),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 44),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 44),
#  ('Diecast Classics Inc.', 157, 10281, 'Shipped', 48),
#  ('Diecast Classics Inc.', 157, 10318, 'Shipped', 26),
#  ('Diecast Classics Inc.', 157, 10318, 'Shipped', 31),
#  ('Diecast Classics Inc.', 157, 10318, 'Shipped', 37),
#  ('Diecast Classics Inc.', 157, 10318, 'Shipped', 42),
#  ('Diecast Classics Inc.', 157, 10318, 'Shipped', 45),
#  ('Diecast Classics Inc.', 157, 10318, 'Shipped', 46),
#  ('Diecast Classics Inc.', 157, 10318, 'Shipped', 47),
#  ('Diecast Classics Inc.', 157, 10318, 'Shipped', 48),
#  ('Diecast Classics Inc.', 157, 10318, 'Shipped', 50),
#  ('Diecast Classics Inc.', 157, 10422, 'In Process', 25),
#  ('Diecast Classics Inc.', 157, 10422, 'In Process', 51),
#  ('Technics Stores Inc.', 161, 10140, 'Shipped', 26),
#  ('Technics Stores Inc.', 161, 10140, 'Shipped', 26),
#  ('Technics Stores Inc.', 161, 10140, 'Shipped', 28),
#  ('Technics Stores Inc.', 161, 10140, 'Shipped', 29),
#  ('Technics Stores Inc.', 161, 10140, 'Shipped', 32),
#  ('Technics Stores Inc.', 161, 10140, 'Shipped', 36),
#  ('Technics Stores Inc.', 161, 10140, 'Shipped', 37),
#  ('Technics Stores Inc.', 161, 10140, 'Shipped', 38),
#  ('Technics Stores Inc.', 161, 10140, 'Shipped', 40),
#  ('Technics Stores Inc.', 161, 10140, 'Shipped', 46),
#  ('Technics Stores Inc.', 161, 10140, 'Shipped', 47),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 20),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 21),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 27),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 27),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 28),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 28),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 29),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 31),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 31),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 36),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 36),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 39),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 46),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 48),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 48),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 48),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 49),
#  ('Technics Stores Inc.', 161, 10168, 'Shipped', 50),
#  ('Technics Stores Inc.', 161, 10317, 'Shipped', 35),
#  ('Technics Stores Inc.', 161, 10362, 'Shipped', 22),
#  ('Technics Stores Inc.', 161, 10362, 'Shipped', 22),
#  ('Technics Stores Inc.', 161, 10362, 'Shipped', 23),
#  ('Technics Stores Inc.', 161, 10362, 'Shipped', 50),
#  ('Handji Gifts& Co', 166, 10217, 'Shipped', 21),
#  ('Handji Gifts& Co', 166, 10217, 'Shipped', 28),
#  ('Handji Gifts& Co', 166, 10217, 'Shipped', 31),
#  ('Handji Gifts& Co', 166, 10217, 'Shipped', 35),
#  ('Handji Gifts& Co', 166, 10217, 'Shipped', 38),
#  ('Handji Gifts& Co', 166, 10217, 'Shipped', 39),
#  ('Handji Gifts& Co', 166, 10217, 'Shipped', 48),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 26),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 27),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 28),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 29),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 30),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 30),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 31),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 34),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 40),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 41),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 45),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 46),
#  ('Handji Gifts& Co', 166, 10259, 'Shipped', 47),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 20),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 23),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 28),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 29),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 31),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 32),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 33),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 34),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 35),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 35),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 36),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 41),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 48),
#  ('Handji Gifts& Co', 166, 10288, 'Shipped', 50),
#  ('Handji Gifts& Co', 166, 10409, 'Shipped', 6),
#  ('Handji Gifts& Co', 166, 10409, 'Shipped', 61),
#  ('Herkku Gifts', 167, 10181, 'Shipped', 20),
#  ('Herkku Gifts', 167, 10181, 'Shipped', 21),
#  ('Herkku Gifts', 167, 10181, 'Shipped', 22),
#  ('Herkku Gifts', 167, 10181, 'Shipped', 22),
#  ('Herkku Gifts', 167, 10181, 'Shipped', 23),
#  ...]

# %% [markdown]
# #### Expected Output
#
# <img src='images/joins.png' width='500' height='600'>
#
# ## HAVING and ORDER BY
#
# Now, return the customerName, customerNumber, productName, productCode, and total number ordered for any product a customer has bought 10 or more of cumulatively. Sort the rows in descending order by the quantity ordered.
#
# **_Hint_**: For this one, you'll need to make use of HAVING, GROUP BY, and ORDER BY -- make sure you get the order of them correct!

# %%
c.execute("""SELECT c.customerName, c.customerNumber,
                    p.productName, p.productCode, sum(od.quantityOrdered) as TotalOrdered
            FROM customers c JOIN orders o
                             ON c.customerNumber = o.customerNumber
                             JOIN orderdetails od
                             ON o.orderNumber = od.orderNumber
                             JOIN products p
                             ON od.productCode = p.productCode
            GROUP BY c.customerName, p.productCode
            HAVING SUM(od.quantityOrdered) >= 10
            ORDER BY totalOrdered DESC""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#                        customerName  customerNumber  \
# 0            Euro+ Shopping Channel             141
# 1            Euro+ Shopping Channel             141
# 2            Euro+ Shopping Channel             141
# 3            Euro+ Shopping Channel             141
# 4            Euro+ Shopping Channel             141
# ...                             ...             ...
# 2526      The Sharp Gifts Warehouse             450
# 2527              La Rochelle Gifts             119
# 2528        Tekni Collectables Inc.             328
# 2529  Extreme Desk Decorations, Ltd             412
# 2530                     Petit Auto             314
#
#                               productName productCode  TotalOrdered
# 0             1992 Ferrari 360 Spider red    S18_3232           308
# 1     1958 Chevy Corvette Limited Edition    S24_2840           245
# 2                      1970 Dodge Coronet    S24_1444           197
# 3                       1957 Chevy Pickup    S12_4473           183
# 4                     2002 Chevy Corvette    S24_3432           174
# ...                                   ...         ...           ...
# 2526            1969 Chevrolet Camaro Z28    S24_3191            13
# 2527          1954 Greyhound Scenicruiser    S32_2509            11
# 2528          American Airlines: B767-300   S700_1691            11
# 2529                1961 Chevrolet Impala    S24_4620            10
# 2530          1913 Ford Model T Speedster    S18_2949            10
#
# [2531 rows x 5 columns]

# %% [markdown]
# #### Expected Output
#
# <img src='images/having_order.png'>
#
# ## Subqueries
#
# Finally, get the first name, last name, employee number, and office code for employees from offices with less than 5 employees. Print the first five rows of this DataFrame.

# %%
c.execute("""SELECT lastName, firstName, employeeNumber, officeCode
                    FROM employees
                    WHERE officeCode IN
                    (SELECT officeCode 
                        FROM offices 
                        JOIN employees
                        USING(officeCode)
                        GROUP BY officeCode
                        HAVING COUNT(employeeNumber) < 5)""").fetchall()
# Out:
# [('Patterson', 'William', 1088, 6),
#  ('Firrelli', 'Julie', 1188, 2),
#  ('Patterson', 'Steve', 1216, 2),
#  ('Tseng', 'Foon Yue', 1286, 3),
#  ('Vanauf', 'George', 1323, 3),
#  ('Bott', 'Larry', 1501, 7),
#  ('Jones', 'Barry', 1504, 7),
#  ('Fixter', 'Andy', 1611, 6),
#  ('Marsh', 'Peter', 1612, 6),
#  ('King', 'Tom', 1619, 6),
#  ('Nishi', 'Mami', 1621, 5),
#  ('Kato', 'Yoshimi', 1625, 5)]

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-5.png'>
#
# # Summary
#
# In this lesson, we reviewed all the major concepts and keywords associated with SQL queries!
